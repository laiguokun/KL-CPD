# %%
import numpy as np

#x_file = 'SGP_x_20180418_random.npy'
#y_file = 'SGP_y_20180418_random.npy'
x_file = 'SGP_x_20180418_random.npy'
y_file = 'SGP_y_20180418_random.npy'
X = np.load(x_file)
Y = np.load(y_file)

# %%
import matplotlib.pyplot as plt;
x = X[1,:1000];
y = Y[:1000]
plt.plot(x)

# %%
plt.plot(y)
